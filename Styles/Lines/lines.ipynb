# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

plt.style.use('./lines.mplstyle')

fig, ax = plt.subplots(1, 1,layout='constrained') 

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

ax.plot(x, y)
