# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
plt.style.use('./grid.mplstyle')
# set the extent on the axes 
# default
fig, ax = plt.subplots(figsize=(4, 2.5), layout='constrained')
ax.plot([1, 2, 3], label='Inline label')
# you can add every line2D property to the grid
ax.grid(alpha=0.7, axis='x', which='both')
ax.grid(alpha=0.7, axis='y')
